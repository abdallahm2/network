# %% [markdown]
# <a href="https://colab.research.google.com/github/abdallahm2/network/blob/master/Histogram_%26_IDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import networkx as nx
ER=nx.fast_gnp_random_graph(1000,0.004)
nx.draw(ER, with_labels=True) 
plt.show(nx)

# %%
d=[i[1] for i in list(ER.degree)]
plt.hist(d, 100)
plt.show()

# %%
import matplotlib.pyplot as plt
import networkx as nx
BA=nx.barabasi_albert_graph(1000,2)
nx.draw(BA, with_labels=True) 
plt.show(nx)

# %%
d=[i[1] for i in list(BA.degree)]
plt.hist(d, 100)
plt.show()

# %%
import numpy as np
dBA=[i[1] for i in list(BA.degree)]
dER=[i[1] for i in list(ER.degree)]
IDD = abs(np.subtract(dBA, dER))
LIDD= min(IDD)
print(LIDD)
# Out:
# 0

# %%
plt.hist(IDD,100)
plt.show()
